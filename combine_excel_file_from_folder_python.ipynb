# %% [markdown]
# <a href="https://colab.research.google.com/github/atomiceltaweel/CV/blob/main/combine_excel_file_from_folder_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import glob
import os
import pandas as pd
import numpy as np
pip install xlrd
output = pd.DataFrame()
for file in glob.glob(os.getcwd()+"/*.xlsx"):
    cn = pd.read_excel(file)
    output = output.append(cn)
output.to_csv(os.getcwd()+"\\outPut.csv", index = False, na_rep = "NA", header=None)
print("Completed +::" )
path = "/content"

filenames = glob.glob(path + "/*.xlsx")
print('File names:', filenames)
# Out:
#   File "<ipython-input-1-b6a6578bc3e3>", line 5
#     pip install xlrd
#               ^
# SyntaxError: invalid syntax

# %%
df = pd.DataFrame()
for f in filenames:
    data = pd.read_excel(f, 'Sheet1')
    df = df.append(data)
df

# %%
df.keys()
# Out:
# Index(['الاسم', 'تاريخ الميلاد', 'الادارة التعليمية', 'SID',
#        'لمرتب الاساسى الشهرى', 'المرتب الاساسى السنوى', 'نسبة الصندوق شهريا',
#        'نسبة الصندوق سنويا'],
#       dtype='object')

# %%
del df['نسبة الصندوق سنويا']
del df['SID']
del df['الاسم']

del df['المرتب الاساسى السنوى']
del df['نسبة الصندوق شهريا']
del df['الادارة التعليمية']

# %%
df.keys()
# Out:
# Index(['تاريخ الميلاد', 'لمرتب الاساسى الشهرى'], dtype='object')

# %%
df.head()
# Out:
#   تاريخ الميلاد  لمرتب الاساسى الشهرى  year day month
# 0      19621026               1324.00  1962  26    10
# 1      19620326               1341.85  1962  26    03
# 2      19620728               1304.40  1962  28    07
# 3      19620823               1309.58  1962  23    08
# 4      19620618               1330.28  1962  18    06

# %%
df['تاريخ الميلاد'] = df['تاريخ الميلاد'].apply('{:06}'.format)

df['year'] = df['تاريخ الميلاد'].str[:4]
df['day'] = df['تاريخ الميلاد'].str[6:8]
df['month'] = df['تاريخ الميلاد'].str[4:6]
dft=df['year']
dft.head()
# Out:
# 0    1962
# 1    1962
# 2    1962
# 3    1962
# 4    1962
# Name: year, dtype: object

# %%
df.head()
# Out:
#   تاريخ الميلاد  لمرتب الاساسى الشهرى  year day month
# 0      19621026               1324.00  1962  26    10
# 1      19620326               1341.85  1962  26    03
# 2      19620728               1304.40  1962  28    07
# 3      19620823               1309.58  1962  23    08
# 4      19620618               1330.28  1962  18    06

# %%
df.dtypes
# Out:
# تاريخ الميلاد                   object
# لمرتب الاساسى الشهرى           float64
# year                            object
# day                             object
# month                           object
# DATE                    datetime64[ns]
# dtype: object

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-7d91e3d181e6> in <module>()
#       1 now = datetime.now()
# ----> 2 df['age'] = now - df['تاريخ الميلاد']
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/arraylike.py in __rsub__(self, other)
#     102     @unpack_zerodim_and_defer("__rsub__")
#     103     def __rsub__(self, other):
# --> 104         return self._arith_method(other, roperator.rsub)
#     105
#     106     @unpack_zerodim_and_defer("__mul__")
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in _arith_method(self, other, op)
#    5524
#    5525         with np.errstate(all="ignore"):
# ...

# %%
df.dtypes
X = df.iloc[:,[4,2,3]]
X
# Out:
#       month  year day
# 0        10  1962  26
# 1        03  1962  26
# 2        07  1962  28
# 3        08  1962  23
# 4        06  1962  18
# ...     ...   ...  ..
# 37125    06  1976  20
# 37126    12  1976  18
# 37127    09  1976  05
# 37128    09  1976  02
# 37129    08  1976  29
#
# [1032392 rows x 3 columns]

# %%
df['DATE']=pd.to_datetime(df[['year','month','day']],errors='coerce')
df.head()
# Out:
#   تاريخ الميلاد  لمرتب الاساسى الشهرى  year day month       DATE
# 0      19621026               1324.00  1962  26    10 1962-10-26
# 1      19620326               1341.85  1962  26    03 1962-03-26
# 2      19620728               1304.40  1962  28    07 1962-07-28
# 3      19620823               1309.58  1962  23    08 1962-08-23
# 4      19620618               1330.28  1962  18    06 1962-06-18

# %%
df.dtypes
# Out:
# تاريخ الميلاد                   object
# لمرتب الاساسى الشهرى           float64
# year                            object
# day                             object
# month                           object
# DATE                    datetime64[ns]
# dtype: object

# %%
table = pd.pivot_table(df, values=['تاريخ الميلاد','لمرتب الاساسى الشهرى'], index=['year'], aggfunc={'لمرتب الاساسى الشهرى': np.sum, 'تاريخ الميلاد': np.count_nonzero})
table
# Out:
#       تاريخ الميلاد  لمرتب الاساسى الشهرى
# year
# 1960          36527           51561932.76
# 1961          40880           54042215.17
# 1962          43517           56506236.44
# 1963          43749           55494884.00
# 1964          43748           56847109.77
# 1965          43749           54987624.44
# 1966          43749           54838705.85
# 1967          43749           52729579.56
# 1968          43749           51900651.94
# 1969          43749           53383172.83
# 1970          43749           52445639.58
# 1971          43749           49958643.09
# 1972          43749           49115222.97
# 1973          43749           47944388.88
# 1974          43027           45099666.73
# 1975          43749           45387110.22
# 1976          37130           37886001.67
# 1977          35863           32340595.90
# 1978          30067           28567845.50
# 1979          32147           28632252.99
# 1980          30799           28463934.99
# ...

# %%
table.to_excel('test.xlsx', sheet_name='sheet1')

# %%
df['تاريخ الميلاد'] = df['تاريخ الميلاد'].astype(int)

# %%
now = datetime.now()
df['age'] = now - df['تاريخ الميلاد']

# %%
df['تاريخ الميلاد'] = pd.to_datetime(df['تاريخ الميلاد'], format='%Y%m%d')

print (df)
print (df.dtypes)
from datetime import datetime, date
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/tools/datetimes.py in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     508         try:
# --> 509             values, tz = conversion.datetime_to_datetime64(arg)
#     510             dta = DatetimeArray(values, dtype=tz_to_dtype(tz))
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-008616eabbe8> in <module>()
#       1
# ----> 2 df['تاريخ الميلاد'] = pd.to_datetime(df['تاريخ الميلاد'], format='%Y%m%d')
#       3
# ...

# %%
def age(born):
    born = datetime.strptime(born,"%Y%m%d").date()
    today = date.today()
    return today.year - born.year - ((today.month, today.day) < (born.month, born.day))

df['Age'] = df['تاريخ الميلاد'].apply(age)
  
display(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-245731126083> in <module>()
#       4     return today.year - born.year - ((today.month, today.day) < (born.month, born.day))
#       5
# ----> 6 df['Age'] = df['تاريخ الميلاد'].apply(age)
#       7
#       8 display(df)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# ...
